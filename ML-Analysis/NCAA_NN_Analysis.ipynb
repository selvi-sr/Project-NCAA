# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os
import warnings
warnings.simplefilter('ignore')
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from yellowbrick.datasets import load_concrete
from yellowbrick.regressor import ResidualsPlot

# %%
history_data = pd.read_csv(os.path.join('Stage2_NCAA_2013T02018.csv'))
history_data.head()
# Out:
#    outcome  TeamID  Score  NumOT  FGM  FGA  FGM3  FGA3  FTM  FTA  OR  DR  Ast  \
# 0        1    1104     70      0   25   52     6    21   14   14   8  19   14
# 1        1    1107     69      0   28   61     7    19    6    7  14  21   13
# 2        1    1114     84      0   28   61     6    17   22   30  11  28   16
# 3        1    1116     73      0   22   51     3    13   26   32   7  16   16
# 4        1    1120     61      0   22   54     3    11   14   21  12  30   10
#
#    TO  Stl  Blk  PF
# 0  12    8    4  16
# 1  12    6    2  22
# 2  14    9    4  19
# 3   9    9    8  14
# 4  16   10    3  17

# %%
# Assign X (data) and y (target)
X = history_data.drop("outcome", axis=1)
y = history_data["outcome"]
print(X.shape, y.shape)
# Out:
# (64410, 16) (64410,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=36, activation='relu', input_dim=16))
model.add(Dense(units=36, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 36)                612
# _________________________________________________________________
# dense_1 (Dense)              (None, 36)                1332
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 74
# =================================================================
# Total params: 2,018
# Trainable params: 2,018
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
 model.fit(
    X_train_scaled,
    y_train,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 48307 samples
# Epoch 1/60
# 48307/48307 - 3s - loss: 0.3047 - accuracy: 0.8654
# Epoch 2/60
# 48307/48307 - 3s - loss: 0.2739 - accuracy: 0.8802
# Epoch 3/60
# 48307/48307 - 3s - loss: 0.2714 - accuracy: 0.8810
# Epoch 4/60
# 48307/48307 - 3s - loss: 0.2700 - accuracy: 0.8827
# Epoch 5/60
# 48307/48307 - 3s - loss: 0.2693 - accuracy: 0.8824
# Epoch 6/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8824
# Epoch 7/60
# 48307/48307 - 2s - loss: 0.2679 - accuracy: 0.8824
# Epoch 8/60
# 48307/48307 - 3s - loss: 0.2670 - accuracy: 0.8836
# Epoch 9/60
# 48307/48307 - 2s - loss: 0.2661 - accuracy: 0.8841
# Epoch 10/60
# 48307/48307 - 3s - loss: 0.2656 - accuracy: 0.8831
# Epoch 11/60
# 48307/48307 - 3s - loss: 0.2655 - accuracy: 0.8842
# Epoch 12/60
# 48307/48307 - 3s - loss: 0.2644 - accuracy: 0.8843
# Epoch 13/60
# 48307/48307 - 3s - loss: 0.2638 - accuracy: 0.8847
# Epoch 14/60
# 48307/48307 - 3s - loss: 0.2636 - accuracy: 0.8852
# Epoch 15/60
# 48307/48307 - 3s - loss: 0.2627 - accuracy: 0.8857
# Epoch 16/60
# 48307/48307 - 3s - loss: 0.2624 - accuracy: 0.8854
# Epoch 17/60
# 48307/48307 - 2s - loss: 0.2617 - accuracy: 0.8855
# Epoch 18/60
# 48307/48307 - 2s - loss: 0.2615 - accuracy: 0.8847
# Epoch 19/60
# 48307/48307 - 3s - loss: 0.2612 - accuracy: 0.8866
# Epoch 20/60
# 48307/48307 - 3s - loss: 0.2605 - accuracy: 0.8861
# Epoch 21/60
# 48307/48307 - 3s - loss: 0.2603 - accuracy: 0.8853
# Epoch 22/60
# 48307/48307 - 2s - loss: 0.2600 - accuracy: 0.8864
# Epoch 23/60
# 48307/48307 - 3s - loss: 0.2593 - accuracy: 0.8872
# Epoch 24/60
# 48307/48307 - 3s - loss: 0.2588 - accuracy: 0.8870
# Epoch 25/60
# 48307/48307 - 3s - loss: 0.2589 - accuracy: 0.8875
# Epoch 26/60
# 48307/48307 - 3s - loss: 0.2585 - accuracy: 0.8877
# Epoch 27/60
# 48307/48307 - 3s - loss: 0.2586 - accuracy: 0.8867
# Epoch 28/60
# 48307/48307 - 3s - loss: 0.2577 - accuracy: 0.8864
# Epoch 29/60
# 48307/48307 - 2s - loss: 0.2576 - accuracy: 0.8876
# Epoch 30/60
# 48307/48307 - 3s - loss: 0.2569 - accuracy: 0.8881
# Epoch 31/60
# 48307/48307 - 2s - loss: 0.2571 - accuracy: 0.8880
# Epoch 32/60
# 48307/48307 - 2s - loss: 0.2565 - accuracy: 0.8880
# Epoch 33/60
# 48307/48307 - 3s - loss: 0.2562 - accuracy: 0.8877
# Epoch 34/60
# 48307/48307 - 2s - loss: 0.2561 - accuracy: 0.8875
# Epoch 35/60
# 48307/48307 - 2s - loss: 0.2555 - accuracy: 0.8881
# Epoch 36/60
# 48307/48307 - 3s - loss: 0.2553 - accuracy: 0.8888
# Epoch 37/60
# 48307/48307 - 3s - loss: 0.2553 - accuracy: 0.8882
# Epoch 38/60
# 48307/48307 - 3s - loss: 0.2546 - accuracy: 0.8883
# Epoch 39/60
# 48307/48307 - 2s - loss: 0.2542 - accuracy: 0.8893
# Epoch 40/60
# 48307/48307 - 3s - loss: 0.2543 - accuracy: 0.8892
# Epoch 41/60
# 48307/48307 - 3s - loss: 0.2537 - accuracy: 0.8886
# Epoch 42/60
# 48307/48307 - 3s - loss: 0.2533 - accuracy: 0.8893
# Epoch 43/60
# 48307/48307 - 3s - loss: 0.2532 - accuracy: 0.8895
# Epoch 44/60
# 48307/48307 - 3s - loss: 0.2530 - accuracy: 0.8894
# Epoch 45/60
# 48307/48307 - 3s - loss: 0.2529 - accuracy: 0.8895
# Epoch 46/60
# 48307/48307 - 3s - loss: 0.2523 - accuracy: 0.8894
# Epoch 47/60
# 48307/48307 - 4s - loss: 0.2520 - accuracy: 0.8894
# Epoch 48/60
# 48307/48307 - 2s - loss: 0.2525 - accuracy: 0.8892
# Epoch 49/60
# 48307/48307 - 3s - loss: 0.2522 - accuracy: 0.8901
# Epoch 50/60
# 48307/48307 - 3s - loss: 0.2512 - accuracy: 0.8902
# Epoch 51/60
# 48307/48307 - 2s - loss: 0.2515 - accuracy: 0.8896
# Epoch 52/60
# 48307/48307 - 3s - loss: 0.2513 - accuracy: 0.8904
# Epoch 53/60
# 48307/48307 - 2s - loss: 0.2506 - accuracy: 0.8909
# Epoch 54/60
# 48307/48307 - 3s - loss: 0.2510 - accuracy: 0.8907
# Epoch 55/60
# 48307/48307 - 3s - loss: 0.2510 - accuracy: 0.8895
# Epoch 56/60
# 48307/48307 - 2s - loss: 0.2511 - accuracy: 0.8905
# Epoch 57/60
# 48307/48307 - 2s - loss: 0.2504 - accuracy: 0.8898
# Epoch 58/60
# 48307/48307 - 3s - loss: 0.2500 - accuracy: 0.8900
# Epoch 59/60
# 48307/48307 - 3s - loss: 0.2502 - accuracy: 0.8904
# Epoch 60/60
# 48307/48307 - 3s - loss: 0.2495 - accuracy: 0.8909

# %%
deep_model = Sequential()
deep_model.add(Dense(units=6, activation='relu', input_dim=16))
deep_model.add(Dense(units=6, activation='relu'))
deep_model.add(Dense(units=2, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 6)                 102
# _________________________________________________________________
# dense_4 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 158
# Trainable params: 158
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
deep_model.fit(
    X_train_scaled,
    y_train,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 48307 samples
# Epoch 1/60
# 48307/48307 - 3s - loss: 0.3634 - accuracy: 0.8329
# Epoch 2/60
# 48307/48307 - 3s - loss: 0.2810 - accuracy: 0.8785
# Epoch 3/60
# 48307/48307 - 3s - loss: 0.2750 - accuracy: 0.8814
# Epoch 4/60
# 48307/48307 - 2s - loss: 0.2732 - accuracy: 0.8815
# Epoch 5/60
# 48307/48307 - 3s - loss: 0.2729 - accuracy: 0.8814
# Epoch 6/60
# 48307/48307 - 3s - loss: 0.2720 - accuracy: 0.8821
# Epoch 7/60
# 48307/48307 - 2s - loss: 0.2715 - accuracy: 0.8817
# Epoch 8/60
# 48307/48307 - 3s - loss: 0.2713 - accuracy: 0.8819
# Epoch 9/60
# 48307/48307 - 2s - loss: 0.2712 - accuracy: 0.8818
# Epoch 10/60
# 48307/48307 - 3s - loss: 0.2711 - accuracy: 0.8819
# Epoch 11/60
# 48307/48307 - 2s - loss: 0.2707 - accuracy: 0.8815
# Epoch 12/60
# 48307/48307 - 3s - loss: 0.2705 - accuracy: 0.8824
# Epoch 13/60
# 48307/48307 - 2s - loss: 0.2704 - accuracy: 0.8818
# Epoch 14/60
# 48307/48307 - 3s - loss: 0.2703 - accuracy: 0.8826
# Epoch 15/60
# 48307/48307 - 3s - loss: 0.2702 - accuracy: 0.8822
# Epoch 16/60
# 48307/48307 - 2s - loss: 0.2700 - accuracy: 0.8830
# Epoch 17/60
# 48307/48307 - 2s - loss: 0.2699 - accuracy: 0.8823
# Epoch 18/60
# 48307/48307 - 3s - loss: 0.2698 - accuracy: 0.8819
# Epoch 19/60
# 48307/48307 - 3s - loss: 0.2697 - accuracy: 0.8821
# Epoch 20/60
# 48307/48307 - 2s - loss: 0.2694 - accuracy: 0.8821
# Epoch 21/60
# 48307/48307 - 2s - loss: 0.2694 - accuracy: 0.8826
# Epoch 22/60
# 48307/48307 - 3s - loss: 0.2695 - accuracy: 0.8824
# Epoch 23/60
# 48307/48307 - 2s - loss: 0.2694 - accuracy: 0.8822
# Epoch 24/60
# 48307/48307 - 2s - loss: 0.2690 - accuracy: 0.8829
# Epoch 25/60
# 48307/48307 - 2s - loss: 0.2690 - accuracy: 0.8823
# Epoch 26/60
# 48307/48307 - 3s - loss: 0.2692 - accuracy: 0.8823
# Epoch 27/60
# 48307/48307 - 2s - loss: 0.2690 - accuracy: 0.8830
# Epoch 28/60
# 48307/48307 - 2s - loss: 0.2689 - accuracy: 0.8827
# Epoch 29/60
# 48307/48307 - 3s - loss: 0.2689 - accuracy: 0.8825
# Epoch 30/60
# 48307/48307 - 3s - loss: 0.2687 - accuracy: 0.8837
# Epoch 31/60
# 48307/48307 - 3s - loss: 0.2687 - accuracy: 0.8826
# Epoch 32/60
# 48307/48307 - 3s - loss: 0.2686 - accuracy: 0.8827
# Epoch 33/60
# 48307/48307 - 2s - loss: 0.2687 - accuracy: 0.8829
# Epoch 34/60
# 48307/48307 - 3s - loss: 0.2686 - accuracy: 0.8831
# Epoch 35/60
# 48307/48307 - 3s - loss: 0.2685 - accuracy: 0.8825
# Epoch 36/60
# 48307/48307 - 3s - loss: 0.2688 - accuracy: 0.8824
# Epoch 37/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8821
# Epoch 38/60
# 48307/48307 - 3s - loss: 0.2685 - accuracy: 0.8830
# Epoch 39/60
# 48307/48307 - 2s - loss: 0.2684 - accuracy: 0.8829
# Epoch 40/60
# 48307/48307 - 2s - loss: 0.2688 - accuracy: 0.8825
# Epoch 41/60
# 48307/48307 - 2s - loss: 0.2684 - accuracy: 0.8829
# Epoch 42/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8829
# Epoch 43/60
# 48307/48307 - 2s - loss: 0.2683 - accuracy: 0.8823
# Epoch 44/60
# 48307/48307 - 2s - loss: 0.2682 - accuracy: 0.8830
# Epoch 45/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8827
# Epoch 46/60
# 48307/48307 - 2s - loss: 0.2684 - accuracy: 0.8836
# Epoch 47/60
# 48307/48307 - 2s - loss: 0.2683 - accuracy: 0.8827
# Epoch 48/60
# 48307/48307 - 2s - loss: 0.2684 - accuracy: 0.8827
# Epoch 49/60
# 48307/48307 - 2s - loss: 0.2683 - accuracy: 0.8831
# Epoch 50/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8824
# Epoch 51/60
# 48307/48307 - 2s - loss: 0.2682 - accuracy: 0.8832
# Epoch 52/60
# 48307/48307 - 2s - loss: 0.2683 - accuracy: 0.8833
# Epoch 53/60
# 48307/48307 - 2s - loss: 0.2683 - accuracy: 0.8832
# Epoch 54/60
# 48307/48307 - 2s - loss: 0.2682 - accuracy: 0.8831
# Epoch 55/60
# 48307/48307 - 3s - loss: 0.2682 - accuracy: 0.8834
# Epoch 56/60
# 48307/48307 - 2s - loss: 0.2682 - accuracy: 0.8829
# Epoch 57/60
# 48307/48307 - 2s - loss: 0.2682 - accuracy: 0.8834
# Epoch 58/60
# 48307/48307 - 2s - loss: 0.2683 - accuracy: 0.8834
# Epoch 59/60
# 48307/48307 - 2s - loss: 0.2679 - accuracy: 0.8832
# Epoch 60/60
# 48307/48307 - 2s - loss: 0.2683 - accuracy: 0.8831

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 16103/16103 - 1s - loss: 0.2824 - accuracy: 0.8782
# Normal Neural Network - Loss: 0.28237016006285365, Accuracy: 0.8782214522361755

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 16103/16103 - 1s - loss: 0.2648 - accuracy: 0.8852
# Deep Neural Network - Loss: 0.2647704842119774, Accuracy: 0.8851766586303711

# %%
Edeep_model = Sequential()
Edeep_model.add(Dense(units=6, activation='relu', input_dim=16))
Edeep_model.add(Dense(units=6, activation='relu'))
Edeep_model.add(Dense(units=6, activation='relu'))
Edeep_model.add(Dense(units=2, activation='softmax'))

# %%
Edeep_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 6)                 102
# _________________________________________________________________
# dense_7 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_9 (Dense)              (None, 2)                 14
# =================================================================
# Total params: 200
# Trainable params: 200
# Non-trainable params: 0
# _________________________________________________________________

# %%
Edeep_model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
Edeep_model.fit(
    X_train_scaled,
    y_train,
    epochs=60,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 48307 samples
# Epoch 1/60
# 48307/48307 - 3s - loss: 0.3674 - accuracy: 0.8343
# Epoch 2/60
# 48307/48307 - 2s - loss: 0.2788 - accuracy: 0.8789
# Epoch 3/60
# 48307/48307 - 2s - loss: 0.2735 - accuracy: 0.8808
# Epoch 4/60
# 48307/48307 - 2s - loss: 0.2725 - accuracy: 0.8819
# Epoch 5/60
# 48307/48307 - 2s - loss: 0.2718 - accuracy: 0.8822
# Epoch 6/60
# 48307/48307 - 2s - loss: 0.2715 - accuracy: 0.8827
# Epoch 7/60
# 48307/48307 - 2s - loss: 0.2710 - accuracy: 0.8817
# Epoch 8/60
# 48307/48307 - 2s - loss: 0.2707 - accuracy: 0.8827
# Epoch 9/60
# 48307/48307 - 2s - loss: 0.2703 - accuracy: 0.8826
# Epoch 10/60
# 48307/48307 - 2s - loss: 0.2703 - accuracy: 0.8815
# Epoch 11/60
# 48307/48307 - 2s - loss: 0.2701 - accuracy: 0.8819
# Epoch 12/60
# 48307/48307 - 2s - loss: 0.2701 - accuracy: 0.8824
# Epoch 13/60
# 48307/48307 - 2s - loss: 0.2698 - accuracy: 0.8824
# Epoch 14/60
# 48307/48307 - 2s - loss: 0.2697 - accuracy: 0.8832
# Epoch 15/60
# 48307/48307 - 2s - loss: 0.2695 - accuracy: 0.8822
# Epoch 16/60
# 48307/48307 - 2s - loss: 0.2694 - accuracy: 0.8827
# Epoch 17/60
# 48307/48307 - 2s - loss: 0.2695 - accuracy: 0.8825
# Epoch 18/60
# 48307/48307 - 2s - loss: 0.2694 - accuracy: 0.8829
# Epoch 19/60
# 48307/48307 - 2s - loss: 0.2693 - accuracy: 0.8825
# Epoch 20/60
# 48307/48307 - 2s - loss: 0.2692 - accuracy: 0.8825
# Epoch 21/60
# 48307/48307 - 2s - loss: 0.2690 - accuracy: 0.8822
# Epoch 22/60
# 48307/48307 - 2s - loss: 0.2692 - accuracy: 0.8819
# Epoch 23/60
# 48307/48307 - 2s - loss: 0.2693 - accuracy: 0.8831
# Epoch 24/60
# 48307/48307 - 2s - loss: 0.2691 - accuracy: 0.8832
# Epoch 25/60
# 48307/48307 - 2s - loss: 0.2691 - accuracy: 0.8828
# Epoch 26/60
# 48307/48307 - 2s - loss: 0.2691 - accuracy: 0.8829
# Epoch 27/60
# 48307/48307 - 2s - loss: 0.2689 - accuracy: 0.8829
# Epoch 28/60
# 48307/48307 - 2s - loss: 0.2689 - accuracy: 0.8824
# Epoch 29/60
# 48307/48307 - 2s - loss: 0.2690 - accuracy: 0.8824
# Epoch 30/60
# 48307/48307 - 2s - loss: 0.2688 - accuracy: 0.8827
# Epoch 31/60
# 48307/48307 - 2s - loss: 0.2688 - accuracy: 0.8823
# Epoch 32/60
# 48307/48307 - 2s - loss: 0.2688 - accuracy: 0.8828
# Epoch 33/60
# 48307/48307 - 2s - loss: 0.2688 - accuracy: 0.8828
# Epoch 34/60
# 48307/48307 - 2s - loss: 0.2689 - accuracy: 0.8825
# Epoch 35/60
# 48307/48307 - 2s - loss: 0.2689 - accuracy: 0.8830
# Epoch 36/60
# 48307/48307 - 2s - loss: 0.2690 - accuracy: 0.8818
# Epoch 37/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8820
# Epoch 38/60
# 48307/48307 - 2s - loss: 0.2688 - accuracy: 0.8826
# Epoch 39/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8825
# Epoch 40/60
# 48307/48307 - 2s - loss: 0.2688 - accuracy: 0.8831
# Epoch 41/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8824
# Epoch 42/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8824
# Epoch 43/60
# 48307/48307 - 2s - loss: 0.2684 - accuracy: 0.8834
# Epoch 44/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8831
# Epoch 45/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8828
# Epoch 46/60
# 48307/48307 - 2s - loss: 0.2684 - accuracy: 0.8827
# Epoch 47/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8831
# Epoch 48/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8832
# Epoch 49/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8830
# Epoch 50/60
# 48307/48307 - 2s - loss: 0.2683 - accuracy: 0.8830
# Epoch 51/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8830
# Epoch 52/60
# 48307/48307 - 2s - loss: 0.2687 - accuracy: 0.8826
# Epoch 53/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8832
# Epoch 54/60
# 48307/48307 - 2s - loss: 0.2688 - accuracy: 0.8830
# Epoch 55/60
# 48307/48307 - 2s - loss: 0.2684 - accuracy: 0.8826
# Epoch 56/60
# 48307/48307 - 2s - loss: 0.2686 - accuracy: 0.8825
# Epoch 57/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8826
# Epoch 58/60
# 48307/48307 - 2s - loss: 0.2687 - accuracy: 0.8829
# Epoch 59/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8820
# Epoch 60/60
# 48307/48307 - 2s - loss: 0.2685 - accuracy: 0.8823

# %%
model_loss, model_accuracy = Edeep_model.evaluate(
    X_test_scaled, y_test, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 16103/16103 - 1s - loss: 0.2671 - accuracy: 0.8842
# Normal Neural Network - Loss: 0.2671042783233843, Accuracy: 0.8842451572418213

# %%
from sklearn.metrics import classification_report

# %%
encoded_predictions = Edeep_model.predict_classes(X_test_scaled)
encoded_predictions
# Out:
# array([1, 0, 1, ..., 0, 0, 1])

# %%
target_names = ['Loss', 'Won']

# %%
print(classification_report(y_test, encoded_predictions, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Loss       0.89      0.88      0.88      8052
#          Won       0.88      0.89      0.88      8051
#
#     accuracy                           0.88     16103
#    macro avg       0.88      0.88      0.88     16103
# weighted avg       0.88      0.88      0.88     16103

# %%
test = pd.read_csv(os.path.join('2019.csv'))
test.head()
# Out:
#    outcome  TeamID  Score  NumOT  FGM  FGA  FGM3  FGA3  FTM  FTA  OR  DR  Ast  \
# 0        1    1104     82      0   27   55     9    24   19   28  16  29   17
# 1        1    1113    102      0   33   78    10    26   26   44  20  38   11
# 2        1    1119     73      0   22   51     9    30   20   29   6  22   14
# 3        1    1120    101      0   38   74    18    38    7   14  19  23   24
# 4        1    1123     86      0   32   65     7    19   15   20  16  26   14
#
#    TO  Stl  Blk  PF
# 0  20    3    6  24
# 1  17    3    2  26
# 2   6    5    1  22
# 3  13    9    8  21
# 4   9    7    5  18

# %%
test.isnull().sum()
# Out:
# outcome    0
# TeamID     0
# Score      0
# NumOT      0
# FGM        0
# FGA        0
# FGM3       0
# FGA3       0
# FTM        0
# FTA        0
# OR         0
# DR         0
# Ast        0
# TO         0
# Stl        0
# Blk        0
# PF         0
# dtype: int64

# %%
# X = test.drop(["outcome", "wpf"], axis=1)
X = test.drop("outcome", axis=1)
y = test["outcome"]
print(X.shape, y.shape)
# Out:
# (10926, 16) (10926,)

# %%
#To predict outcome for 2019 dataset
encoded_predictions2 = deep_model.predict_classes(X)
encoded_predictions2
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(classification_report(y, encoded_predictions2, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         Loss       0.58      0.99      0.73      5463
#          Won       0.98      0.26      0.42      5463
#
#     accuracy                           0.63     10926
#    macro avg       0.78      0.63      0.57     10926
# weighted avg       0.78      0.63      0.57     10926

# %%
pd.DataFrame({"Prediction": encoded_predictions2, "Actual": y}).reset_index(drop=True)
# Out:
#        Prediction  Actual
# 0               0       1
# 1               0       1
# 2               0       1
# 3               1       1
# 4               1       1
# 5               0       1
# 6               0       1
# 7               0       1
# 8               0       1
# 9               0       1
# 10              0       1
# 11              1       1
# 12              0       1
# 13              1       1
# 14              0       1
# 15              0       1
# 16              0       1
# 17              1       1
# 18              1       1
# 19              0       1
# 20              0       1
# 21              1       1
# 22              0       1
# 23              0       1
# 24              1       1
# 25              0       1
# 26              0       1
# 27              1       1
# 28              0       1
# 29              0       1
# ...           ...     ...
# 10896           0       0
# 10897           0       0
# 10898           0       0
# 10899           0       0
# 10900           0       0
# 10901           0       0
# 10902           0       0
# 10903           0       0
# 10904           0       0
# 10905           0       0
# 10906           0       0
# 10907           0       0
# 10908           0       0
# 10909           0       0
# 10910           0       0
# 10911           0       0
# 10912           0       0
# 10913           0       0
# 10914           0       0
# 10915           0       0
# 10916           0       0
# 10917           0       0
# 10918           0       0
# 10919           0       0
# 10920           0       0
# 10921           0       0
# 10922           0       0
# 10923           0       0
# 10924           0       0
# 10925           0       0
#
# [10926 rows x 2 columns]

# %%
temp_df = pd.DataFrame()

# %%
temp_df['prediction'] = encoded_predictions2
temp_df['actual'] = y.tolist()

# %%
temp_df["TeamID"]=X["TeamID"].tolist()

# %%
output_File = "predictions_NN_2019-1.csv"

# %%
temp_df.to_csv(output_File,index=False)

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X, y, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 10926/10926 - 0s - loss: 10.1631 - accuracy: 0.6299
# Normal Neural Network - Loss: 10.163063330935568, Accuracy: 0.6298736929893494
